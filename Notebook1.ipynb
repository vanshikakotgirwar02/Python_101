# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
name = "vanshika"
age = 20
hieght = 5.1
vanshika_list = [1,2,3,4,5,6,7,8,9]
vanshika_Dict = {
    "Branch" : "cse",
    "Roll no" : 34,
    "cgpa" : 9.0,
    "section" : "B",
    "above 18" : True


}

# %%
print("name:", name)
print("age:", age)
print("hieght:", hieght)
print("vanshika_list:", vanshika_list)
print("vanshika_Dict:", vanshika_Dict)
# Out:
# name: vanshika
# age: 20
# hieght: 5.1
# vanshika_list: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# vanshika_Dict: {'Branch': 'cse', 'Roll no': 34, 'cgpa': 9.0, 'section': 'B', 'above 18': True}
