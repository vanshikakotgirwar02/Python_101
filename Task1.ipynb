# %%
amount = float(input("enter amount:"))
print(amount)

if amount >= 5000:
    discount = 0.14
elif amount > 1000:
    discount = 0.10
elif amount >= 500:
    discount = 0.06
else:
    print("invalid amount")
    print(f"total amount is {amount} \n total amount after discount: {amount - (amount * 0)}")
# Out:
# 1156.0
