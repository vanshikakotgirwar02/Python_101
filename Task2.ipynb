# %%
def choice():
    while True:
       a =input("enter input:")

       if a == "s":
            print("Valid")
            break
       else:
            print("Invalid")

# %%
choice()
# Out:
# Invalid
# Invalid
# Invalid
# Valid

# %%
list =[10,20,30,40,50]

# %%
for element in list:
    print(element)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
search_item = 10
for element in list:
    if element == search_item:
       print("item found",element)
       break
    else:
       print("invalid")
# Out:
# item found 10

# %%
new_dict = {"item1": "pen", "item2": "pencil", "item3": "sharpner"}

# %%
for i,j in new_dict.items():
    if i == "item1":
        print(j)
    else:
        print("no element found")
# Out:
# pen
# no element found
# no element found

# %%
list1 = [10,67,34,56,98]

# %%
list1.append(24) #append
print(list1)

list1.insert(2,45) #insert
print(list1)

list1.count(34) #count
print(list1)
# Out:
# [10, 67, 34, 56, 98, 24]
# [10, 67, 45, 34, 56, 98, 24]
# [10, 67, 45, 34, 56, 98, 24]

# %%
list_of_squares=[]
for i in range(1,13):
    list_of_squares.append(i*i)

    
list_of_squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]

# %%
list_of_sq = [x*x for x in range(1,13)]#list comprehension
list_of_sq
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144]
